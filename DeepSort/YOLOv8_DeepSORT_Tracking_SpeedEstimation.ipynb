# %% [markdown]
# # Before Running the Script Please Make Sure you Select the Run Time as GPU

# %% [markdown]
# ![%7B4982E371-F185-4235-83B9-A5CF52E2B220%7D.png](attachment:%7B4982E371-F185-4235-83B9-A5CF52E2B220%7D.png)

# %% [markdown]
# https://www.youtube.com/watch?v=nIbFnuN2cCI&t=17s  - Turkish
#
# https://www.youtube.com/watch?v=-O19-7CYNko  - YOLO11 - English

# %% [markdown]
# # Clone the Github Repo

# %%
# !git clone https://github.com/MuhammadMoinFaisal/YOLOv8-DeepSORT-Object-Tracking.git
# Out:
# fatal: destination path 'YOLOv8-DeepSORT-Object-Tracking' already exists and is not an empty directory.

# %% [markdown]
# ## Setting the Current Directory

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking
# Out:
# [WinError 3] The system cannot find the path specified: '/content/YOLOv8-DeepSORT-Object-Tracking'
# C:\Users\ismet\OneDrive - University of Strathclyde\Desktop\TechPro\3 - DL\Ismet\13 - CV - OCR\DeepSort

# %% [markdown]
# ## Install all the Dependencies

# %%
# !pip install -e '.[dev]'
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: '.[dev]' is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).

# %% [markdown]
# ## Moving to the Required Directory

# %%
# %cd /content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect
# Out:
# [WinError 3] The system cannot find the path specified: '/content/YOLOv8-DeepSORT-Object-Tracking/ultralytics/yolo/v8/detect'
# C:\Users\ismet\OneDrive - University of Strathclyde\Desktop\TechPro\3 - DL\Ismet\13 - CV - OCR\DeepSort

# %% [markdown]
# ## To implement the DeepSORT tracking, downloading the required files

# %%
# !pip install gdown
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gdown

gdown.download("https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf", output="file_name .ext", quiet=False)

# !gdown "https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf
# From (redirected): https://drive.google.com/uc?id=11ZSZcG-bcbueXZC3rN08CM0qqX3eiHxf&confirm=t&uuid=4d6e5cac-7b01-4606-8092-6c609d2608e3
# To: C:\Users\ismet\OneDrive - University of Strathclyde\Desktop\TechPro\3 - DL\Ismet\13 - CV - OCR\DeepSort\dosya_adi.ext
# 100%|█████████████████████████████████████████████████████████████████████████████| 43.1M/43.1M [00:12<00:00, 3.34MB/s]
# 'dosya_adi.ext'

# %% [markdown]
# ## Unzipping the DeepSORT Files

# %%
# !unzip 'deep_sort_pytorch.zip'
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
"""import zipfile

# Define the path of the zip file and the extraction folder
zip_file_path = 'deep_sort_pytorch.zip'
extract_path = './'  # Specify the folder to extract to, e.g., './' for the current directory

# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("File extracted successfully.")"""
# Out:
# 'import zipfile\n\n# Define the path of the zip file and the extraction folder\nzip_file_path = \'deep_sort_pytorch.zip\'\nextract_path = \'./\'  # Specify the folder to extract to, e.g., \'./\' for the current directory\n\n# Extract the zip file\nwith zipfile.ZipFile(zip_file_path, \'r\') as zip_ref:\n    zip_ref.extractall(extract_path)\n\nprint("File extracted successfully.")'

# %% [markdown]
# ##Download a Sample Video for Testing from Google Drive

# %%
# !gdown https://drive.google.com/uc?id=1_kt1alzcLRVxet-Drx0mt_KFSd3vrtHU
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1_kt1alzcLRVxet-Drx0mt_KFSd3vrtHU
# To: C:\Users\ismet\OneDrive - University of Strathclyde\Desktop\TechPro\3 - DL\Ismet\13 - CV - OCR\DeepSort\test1.mp4
#
#   0%|          | 0.00/6.11M [00:00<?, ?B/s]
#   9%|8         | 524k/6.11M [00:00<00:02, 2.54MB/s]
#  17%|#7        | 1.05M/6.11M [00:00<00:01, 3.19MB/s]
#  26%|##5       | 1.57M/6.11M [00:00<00:01, 3.69MB/s]
#  34%|###4      | 2.10M/6.11M [00:00<00:01, 2.85MB/s]
#  43%|####2     | 2.62M/6.11M [00:00<00:01, 3.39MB/s]
#  52%|#####1    | 3.15M/6.11M [00:01<00:01, 2.86MB/s]
#  60%|######    | 3.67M/6.11M [00:01<00:00, 2.45MB/s]
#  69%|######8   | 4.19M/6.11M [00:01<00:00, 2.48MB/s]
#  77%|#######7  | 4.72M/6.11M [00:01<00:00, 2.83MB/s]
#  86%|########5 | 5.24M/6.11M [00:01<00:00, 3.06MB/s]
#  94%|#########4| 5.77M/6.11M [00:01<00:00, 3.33MB/s]
# 100%|##########| 6.11M/6.11M [00:01<00:00, 3.06MB/s]

# %% [markdown]
# ## Lets Run the Script

# %%
# !pip install hydra-core
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !gdown "https://drive.google.com/uc?id=1QZijehoi66eAhNAsy78SnOqatBWfckjl&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1QZijehoi66eAhNAsy78SnOqatBWfckjl&confirm=t
# To: C:\Users\ismet\OneDrive - University of Strathclyde\Desktop\TechPro\3 - DL\Ismet\13 - CV - OCR\DeepSort\predict.py
#
#   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# 100%|##########| 12.9k/12.9k [00:00<00:00, 3.24MB/s]

# %%
# !pip install -U ultralytics
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ismet\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ultralytics
print(dir(ultralytics))
# Out:
# ['ASSETS', 'FastSAM', 'NAS', 'RTDETR', 'SAM', 'SETTINGS', 'YOLO', 'YOLOWorld', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'cfg', 'checks', 'data', 'download', 'engine', 'hub', 'models', 'nn', 'os', 'settings', 'utils']

# %%
from ultralytics import YOLO

# Modeli doğrudan YOLO sınıfı üzerinden kullanabilirsiniz
model = YOLO("yolov8n.pt")  # YOLO model yolunu belirtiyoruz
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 4
#       1 from ultralytics import YOLO
#       3 # Modeli doğrudan YOLO sınıfı üzerinden kullanabilirsiniz
# ----> 4 model = YOLO("yolov8n.pt")
#
# File ~\anaconda3\lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\model.py:145, in Model.__init__(self, model, task, verbose)
#     143     self._new(model, task=task, verbose=verbose)
#     144 else:
# --> 145     self._load(model, task=task)
#
# File ~\anaconda3\lib\site-packages\ultralytics\engine\model.py:285, in Model._load(self, weights, task)
# ...

# %%
from ultralytics import YOLO

# %%
# !python predict.py model=yolov8n.pt source="test1.mp4"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ismet\OneDrive - University of Strathclyde\Desktop\TechPro\3 - DL\Ismet\13 - CV - OCR\DeepSort\predict.py", line 13, in <module>
#     from ultralytics.yolo.engine.predictor import BasePredictor
# ModuleNotFoundError: No module named 'ultralytics.yolo'

# %%
# !python predict.py model=yolov8n.pt source="smooth_traffic.mp4"
# Out:
# Traceback (most recent call last):
#   File "C:\Users\ismet\OneDrive - University of Strathclyde\Desktop\TechPro\3 - DL\Ismet\13 - CV - OCR\DeepSort\predict.py", line 13, in <module>
#     from ultralytics.yolo.engine.predictor import BasePredictor
# ModuleNotFoundError: No module named 'ultralytics.yolo'

# %% [markdown]
# ## Display the Demo Video

# %%
# !rm "/content/result_compressed.mp4"
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/YOLOv8-DeepSORT-Object-Tracking/runs/detect/train6/test1.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 14
#      11 os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")
#      13 # Show video
# ---> 14 mp4 = open(compressed_path,'rb').read()
#      15 data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
#      16 HTML("""
#      17 <video width=400 controls>
#      18       <source src="%s" type="video/mp4">
#      19 </video>
#      20 """ % data_url)
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# ...
