# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Dataset Info</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The Census Income dataset has 32,561 entries. Each entry contains the following information about an individual:
#
# - **salary (target feature/label):** whether or not an individual makes more than $50,000 annually. (<= 50K, >50K)
# - **age:** the age of an individual. (Integer greater than 0)
# - **workclass:** a general term to represent the employment status of an individual. (Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked)
# - **fnlwgt:** this is the number of people the census believes the entry represents. People with similar demographic characteristics should have similar weights.  There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.(Integer greater than 0)
# - **education:** the highest level of education achieved by an individual. (Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.)
# - **education-num:** the highest level of education achieved in numerical form. (Integer greater than 0)
# - **marital-status:** marital status of an individual. Married-civ-spouse corresponds to a civilian spouse while Married-AF-spouse is a spouse in the Armed Forces. Married-spouse-absent includes married people living apart because either the husband or wife was employed and living at a considerable distance from home (Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse)
# - **occupation:** the general type of occupation of an individual. (Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces)
# - **relationship:** represents what this individual is relative to others. For example an individual could be a Husband. Each entry only has one relationship attribute. (Wife, Husband, Not-in-family, Other-relative, Unmarried)
# - **race:** Descriptions of an individual’s race. (White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black)
# - **sex:** the biological sex of the individual. (Male, female)
# - **capital-gain:** capital gains for an individual. (Integer greater than or equal to 0)
# - **capital-loss:** capital loss for an individual. (Integer greater than or equal to 0)
# - **hours-per-week:** the hours an individual has reported to work per week. (continuous)
# - **native-country:** country of origin for an individual (United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read data from file

# %%
df = pd.read_csv("adult_eda.csv")

# %%
df.sample(7)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 31523   49         Local-gov  405309     Assoc-voc           11.0
# 24266   56           Private  238806       7th-8th            4.0
# 26126   31           Private  176831          10th            6.0
# 31167   51  Self-emp-not-inc  134447       HS-grad            9.0
# 386     29           Private  134152       HS-grad            9.0
# 3565    34           Private  157165  Some-college           10.0
# 8137    20  Self-emp-not-inc  263498     Assoc-voc           11.0
#
#            marital-status         occupation    relationship   race     sex  \
# 31523  Married-civ-spouse       Craft-repair         Husband  White    Male
# 24266  Married-civ-spouse       Craft-repair         Husband  White    Male
# 26126            Divorced              Sales  Other-relative  White  Female
# 31167  Married-civ-spouse       Craft-repair         Husband  White    Male
# 386             Separated  Machine-op-inspct   Not-in-family  White    Male
# 3565             Divorced      Other-service       Unmarried  White  Female
# 8137        Never-married    Farming-fishing             NaN  White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 31523             0             0              40  United-States   >50K
# 24266             0             0              26  United-States  <=50K
# 26126             0             0              40  United-States  <=50K
# 31167             0             0              70  United-States  <=50K
# 386               0             0              40  United-States  <=50K
# 3565              0             0              40  United-States  <=50K
# 8137              0             0              40  United-States  <=50K

# %% [markdown]
# ## Try to understand what the data looks like? What are data types of the features? Are there any missing values?

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   31759.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.082843   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.576172   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.isna().sum()[df.isna().sum() > 0]
# Out:
# education-num     802
# relationship     5068
# dtype: int64

# %% [markdown]
# ## Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.sample(25)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 18434   58           Private  116901       HS-grad            9.0
# 7090    41      Self-emp-inc  194636     Bachelors           13.0
# 7292    33           Private  150570     Bachelors           13.0
# 29335   33           Private  323811  Some-college           10.0
# 1405    24           Private  241523       HS-grad            9.0
# 24476   31           Private  263561       Masters           14.0
# 17831   60       Federal-gov   55621    Assoc-acdm           12.0
# 13925   33           Private   93056       7th-8th            4.0
# 9878    28         Local-gov  185647  Some-college           10.0
# 17131   24           Private  133520  Some-college           10.0
# 1154    43         State-gov  165309       HS-grad            9.0
# 10006   29           Private  158218       HS-grad            9.0
# 10874   53           Private  233369  Some-college           10.0
# 13639   36  Self-emp-not-inc   35945       7th-8th            4.0
# 15524   43           Private  142444  Some-college           10.0
# 15891   73           Private   26248       7th-8th            4.0
# 13157   44           Private   42476       HS-grad            9.0
# 22051   21           Private  242912       HS-grad            9.0
# 17823   44  Self-emp-not-inc  149943   Prof-school           15.0
# 30810   28           Private  131298       HS-grad            9.0
# 7142    48           Private   38950       HS-grad            9.0
# 29710   67                 ?  201657     Bachelors           13.0
# 22895   88           Private   68539  Some-college           10.0
# 31653   25           Private  189656     Bachelors           13.0
# 22398   39         State-gov  122011       Masters           14.0
#
#            marital-status         occupation    relationship  \
# 18434            Divorced      Other-service       Unmarried
# 7090   Married-civ-spouse              Sales         Husband
# 7292   Married-civ-spouse              Sales         Husband
# 29335  Married-civ-spouse  Machine-op-inspct         Husband
# 1405   Married-civ-spouse      Other-service         Husband
# 24476  Married-civ-spouse    Exec-managerial         Husband
# 17831  Married-civ-spouse      Other-service         Husband
# 13925            Divorced  Handlers-cleaners             NaN
# 9878   Married-civ-spouse    Protective-serv         Husband
# 17131       Never-married              Sales             NaN
# 1154   Married-civ-spouse    Protective-serv         Husband
# 10006       Never-married    Farming-fishing       Unmarried
# 10874             Widowed    Exec-managerial       Unmarried
# 13639  Married-civ-spouse  Machine-op-inspct         Husband
# 15524            Divorced              Sales       Unmarried
# 15891  Married-civ-spouse              Sales         Husband
# 13157       Never-married       Adm-clerical  Other-relative
# 22051       Never-married      Other-service  Other-relative
# 17823  Married-civ-spouse     Prof-specialty         Husband
# 30810       Never-married      Other-service   Not-in-family
# 7142   Married-civ-spouse       Tech-support         Husband
# 29710            Divorced                  ?   Not-in-family
# 22895            Divorced       Adm-clerical       Unmarried
# 31653       Never-married       Tech-support   Not-in-family
# 22398  Married-civ-spouse     Prof-specialty            Wife
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 18434               White  Female             0             0              25
# 7090                White    Male         99999             0              65
# 7292                White    Male             0             0              40
# 29335               White    Male             0             0              55
# 1405                White    Male             0             0              45
# 24476               White    Male             0             0              40
# 17831               Black    Male             0             0              40
# 13925               White    Male             0             0              40
# 9878                White    Male             0             0              48
# 17131               White  Female             0             0              15
# 1154                White    Male             0             0              40
# 10006               White    Male             0             0              35
# 10874               White  Female             0             0              40
# 13639               White    Male          7298             0              45
# 15524               White  Female             0             0              55
# 15891               White    Male             0             0              30
# 13157               White  Female             0             0              30
# 22051               White  Female             0             0              35
# 17823  Asian-Pac-Islander    Male             0             0              60
# 30810               White    Male             0             0              60
# 7142                White    Male             0             0              89
# 29710               White  Female             0             0              60
# 22895               White  Female             0             0              40
# 31653               White    Male             0             0              60
# 22398               White  Female          5178             0              38
#
#       native-country salary
# 18434  United-States  <=50K
# 7090   United-States   >50K
# 7292   United-States  <=50K
# 29335  United-States  <=50K
# 1405   United-States   >50K
# 24476  United-States   >50K
# 17831  United-States  <=50K
# 13925  United-States  <=50K
# 9878   United-States  <=50K
# 17131  United-States  <=50K
# 1154   United-States  <=50K
# 10006  United-States  <=50K
# 10874  United-States  <=50K
# 13639  United-States   >50K
# 15524  United-States   >50K
# 15891  United-States   >50K
# 13157  United-States  <=50K
# 22051  United-States  <=50K
# 17823         Taiwan   >50K
# 30810  United-States  <=50K
# 7142   United-States  <=50K
# 29710  United-States  <=50K
# 22895  United-States  <=50K
# 31653  United-States   >50K
# 22398  United-States   >50K

# %%
df.select_dtypes('object')
# Out:
#               workclass   education      marital-status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native-country salary
# 0      Not-in-family  White    Male  United-States  <=50K
# 1            Husband  White    Male  United-States  <=50K
# 2      Not-in-family  White    Male  United-States  <=50K
# 3            Husband  Black    Male  United-States  <=50K
# 4               Wife  Black  Female           Cuba  <=50K
# ...              ...    ...     ...            ...    ...
# 32556           Wife  White  Female  United-States  <=50K
# 32557        Husband  White    Male  United-States   >50K
# 32558      Unmarried  White  Female  United-States  <=50K
# 32559            NaN  White    Male  United-States  <=50K
# 32560           Wife  White  Female  United-States   >50K
#
# [32561 rows x 9 columns]

# %%
df.select_dtypes('object').describe()
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
for col in df.select_dtypes("object"):
    print(col)
    print("*********")
    print(df[col].value_counts())
    print("*********\n")
# Out:
# workclass
# *********
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
# *********
#
# education
# *********
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64
# *********
#
# marital-status
# *********
# marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64
# *********
#
# occupation
# *********
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64
# *********
#
# relationship
# *********
# relationship
# Husband           13193
# Not-in-family      8305
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64
# *********
#
# race
# *********
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64
# *********
#
# sex
# *********
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64
# *********
#
# native-country
# *********
# native-country
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64
# *********
#
# salary
# *********
# salary
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64
# *********

# %%
df.isin(['?']).any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country     True
# salary            False
# dtype: bool

# %%
df.isin(['?']).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# salary               0
# dtype: int64

# %%
df.workclass.replace("?", "Unknown", inplace=True)

# %%
df.workclass.value_counts()
# Out:
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64

# %%
df = df.replace("?", "Unknown")

# %%
for col in df.select_dtypes("object"):
    print(col)
    print("*********")
    print(df[col].value_counts())
    print("*********\n")
# Out:
# workclass
# *********
# workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
# *********
#
# education
# *********
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64
# *********
#
# marital-status
# *********
# marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64
# *********
#
# occupation
# *********
# occupation
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# Unknown              1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: count, dtype: int64
# *********
#
# relationship
# *********
# relationship
# Husband           13193
# Not-in-family      8305
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64
# *********
#
# race
# *********
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64
# *********
#
# sex
# *********
# sex
# Male      21790
# Female    10771
# Name: count, dtype: int64
# *********
#
# native-country
# *********
# native-country
# United-States                 29170
# Mexico                          643
# Unknown                         583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Cambodia                         19
# Trinadad&Tobago                  19
# Laos                             18
# Thailand                         18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: count, dtype: int64
# *********
#
# salary
# *********
# salary
# <=50K    24720
# >50K      7841
# Name: count, dtype: int64
# *********

# %%
df.isin(["?"]).sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# ## Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df.tail(15)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 32546   37           Private  198216    Assoc-acdm           12.0
# 32547   43           Private  260761       HS-grad            9.0
# 32548   65  Self-emp-not-inc   99359   Prof-school           15.0
# 32549   43         State-gov  255835  Some-college           10.0
# 32550   43  Self-emp-not-inc   27242  Some-college           10.0
# 32551   32           Private   34066          10th            6.0
# 32552   43           Private   84661     Assoc-voc           11.0
# 32553   32           Private  116138       Masters           14.0
# 32554   53           Private  321865       Masters           14.0
# 32555   22           Private  310152  Some-college           10.0
# 32556   27           Private  257302    Assoc-acdm           12.0
# 32557   40           Private  154374       HS-grad            9.0
# 32558   58           Private  151910       HS-grad            9.0
# 32559   22           Private  201490       HS-grad            9.0
# 32560   52      Self-emp-inc  287927       HS-grad            9.0
#
#            marital-status         occupation    relationship  \
# 32546            Divorced       Tech-support   Not-in-family
# 32547  Married-civ-spouse  Machine-op-inspct         Husband
# 32548       Never-married     Prof-specialty   Not-in-family
# 32549            Divorced       Adm-clerical  Other-relative
# 32550  Married-civ-spouse       Craft-repair         Husband
# 32551  Married-civ-spouse  Handlers-cleaners         Husband
# 32552  Married-civ-spouse              Sales         Husband
# 32553       Never-married       Tech-support   Not-in-family
# 32554  Married-civ-spouse    Exec-managerial         Husband
# 32555       Never-married    Protective-serv   Not-in-family
# 32556  Married-civ-spouse       Tech-support            Wife
# 32557  Married-civ-spouse  Machine-op-inspct         Husband
# 32558             Widowed       Adm-clerical       Unmarried
# 32559       Never-married       Adm-clerical             NaN
# 32560  Married-civ-spouse    Exec-managerial            Wife
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 32546               White  Female             0             0              40
# 32547               White    Male             0             0              40
# 32548               White    Male          1086             0              60
# 32549               White  Female             0             0              40
# 32550               White    Male             0             0              50
# 32551  Amer-Indian-Eskimo    Male             0             0              40
# 32552               White    Male             0             0              45
# 32553  Asian-Pac-Islander    Male             0             0              11
# 32554               White    Male             0             0              40
# 32555               White    Male             0             0              40
# 32556               White  Female             0             0              38
# 32557               White    Male             0             0              40
# 32558               White  Female             0             0              40
# 32559               White    Male             0             0              20
# 32560               White  Female         15024             0              40
#
#       native-country salary
# 32546  United-States  <=50K
# 32547         Mexico  <=50K
# 32548  United-States  <=50K
# 32549  United-States  <=50K
# 32550  United-States  <=50K
# 32551  United-States  <=50K
# 32552  United-States  <=50K
# 32553         Taiwan  <=50K
# 32554  United-States   >50K
# 32555  United-States  <=50K
# 32556  United-States  <=50K
# 32557  United-States   >50K
# 32558  United-States  <=50K
# 32559  United-States  <=50K
# 32560  United-States   >50K

# %%
df.education.value_counts(dropna=False)
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
df["education-num"].value_counts(dropna=False)
# Out:
# education-num
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# NaN       802
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: count, dtype: int64

# %%
df.groupby("education")["education-num"].value_counts(dropna=False)
# Out:
# education     education-num
# 10th          6.0                916
#               NaN                 17
# 11th          7.0               1146
#               NaN                 29
# 12th          8.0                424
#               NaN                  9
# 1st-4th       2.0                161
#               NaN                  7
# 5th-6th       3.0                330
#               NaN                  3
# 7th-8th       4.0                631
#               NaN                 15
# 9th           5.0                503
#               NaN                 11
# Assoc-acdm    12.0              1044
#               NaN                 23
# Assoc-voc     11.0              1343
#               NaN                 39
# Bachelors     13.0              5247
#               NaN                108
# Doctorate     16.0               405
#               NaN                  8
# HS-grad       9.0              10215
#               NaN                286
# Masters       14.0              1687
#               NaN                 36
# Preschool     1.0                 50
#               NaN                  1
# Prof-school   15.0               559
#               NaN                 17
# Some-college  10.0              7098
#               NaN                193
# Name: count, dtype: int64

# %%
df.drop("education-num", inplace=True, axis=1)

# %%
df
# Out:
#        age         workclass  fnlwgt   education      marital-status  \
# 0       39         State-gov   77516   Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311   Bachelors  Married-civ-spouse
# 2       38           Private  215646     HS-grad            Divorced
# 3       53           Private  234721        11th  Married-civ-spouse
# 4       28           Private  338409   Bachelors  Married-civ-spouse
# ...    ...               ...     ...         ...                 ...
# 32556   27           Private  257302  Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374     HS-grad  Married-civ-spouse
# 32558   58           Private  151910     HS-grad             Widowed
# 32559   22           Private  201490     HS-grad       Never-married
# 32560   52      Self-emp-inc  287927     HS-grad  Married-civ-spouse
#
#               occupation   relationship   race     sex  capital-gain  \
# 0           Adm-clerical  Not-in-family  White    Male          2174
# 1        Exec-managerial        Husband  White    Male             0
# 2      Handlers-cleaners  Not-in-family  White    Male             0
# 3      Handlers-cleaners        Husband  Black    Male             0
# 4         Prof-specialty           Wife  Black  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556       Tech-support           Wife  White  Female             0
# 32557  Machine-op-inspct        Husband  White    Male             0
# 32558       Adm-clerical      Unmarried  White  Female             0
# 32559       Adm-clerical            NaN  White    Male             0
# 32560    Exec-managerial           Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 0                 0              40  United-States  <=50K
# 1                 0              13  United-States  <=50K
# 2                 0              40  United-States  <=50K
# 3                 0              40  United-States  <=50K
# 4                 0              40           Cuba  <=50K
# ...             ...             ...            ...    ...
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K
#
# [32561 rows x 14 columns]

# %% [markdown]
# ## Impute missing value in relationship column with "Unmaried". Also replace "Not-in-family", "Other-relative" values in this column with "Unmaried"?

# %%
df.relationship.value_counts(dropna=False)
# Out:
# relationship
# Husband           13193
# Not-in-family      8305
# NaN                5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: count, dtype: int64

# %%
df['marital-status'].value_counts(dropna = False)
# Out:
# marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64

# %%
df.groupby("relationship")['marital-status'].value_counts(dropna = False)
# Out:
# relationship    marital-status
# Husband         Married-civ-spouse       13184
#                 Married-AF-spouse            9
# Not-in-family   Never-married             4706
#                 Divorced                  2404
#                 Widowed                    547
#                 Separated                  420
#                 Married-spouse-absent      211
#                 Married-civ-spouse          17
# Other-relative  Never-married              611
#                 Married-civ-spouse         124
#                 Divorced                   110
#                 Separated                   55
#                 Widowed                     48
#                 Married-spouse-absent       32
#                 Married-AF-spouse            1
# Unmarried       Divorced                  1601
#                 Never-married              881
#                 Separated                  451
#                 Widowed                    383
#                 Married-spouse-absent      130
# Wife            Married-civ-spouse        1556
#                 Married-AF-spouse           12
# Name: count, dtype: int64

# %%
df.relationship.replace(["Not-in-family", "Other-relative", np.nan], "Unmarried", inplace=True)

# %%
df.relationship.value_counts(dropna=False)
# Out:
# relationship
# Unmarried    17800
# Husband      13193
# Wife          1568
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %% [markdown]
# ## Take a look at correlation between variable and also see if there are some outliers in any of the columns

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
df.select_dtypes('number').corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
corr_df = df.select_dtypes('number').corr()
sns.heatmap(data = corr_df, annot=True, cmap="viridis")
# Out:
# <Axes: >

# %% [markdown]
# ## find outlier values which extends the upper limit in both age and hours - per - week columns

# %% [markdown]
# age

# %%
plt.figure(figsize=(8,6))
plt.subplot(1, 2, 1)
sns.boxplot(data = df.age, whis=1.5)
plt.subplot(1, 2, 2)
sns.histplot(data = df.age, bins=10)
# Out:
# C:\Users\jawed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jawed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='age', ylabel='Count'>

# %%
df[df.age > 78]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 74      79           Private  124744  Some-college  Married-civ-spouse
# 222     90           Private   51744       HS-grad       Never-married
# 430     80           Unknown  107762       HS-grad             Widowed
# 918     81  Self-emp-not-inc  136063       HS-grad  Married-civ-spouse
# 1040    90           Private  137018       HS-grad       Never-married
# ...    ...               ...     ...           ...                 ...
# 32277   90           Private  313749       HS-grad             Widowed
# 32367   90         Local-gov  214594       7th-8th  Married-civ-spouse
# 32459   85           Private   98611     Bachelors  Married-civ-spouse
# 32494   82           Unknown  403910       HS-grad       Never-married
# 32525   81           Unknown  120478     Assoc-voc            Divorced
#
#             occupation relationship   race     sex  capital-gain  \
# 74      Prof-specialty    Unmarried  White    Male             0
# 222      Other-service    Unmarried  Black    Male             0
# 430            Unknown    Unmarried  White    Male             0
# 918    Exec-managerial      Husband  White    Male             0
# 1040     Other-service    Unmarried  White  Female             0
# ...                ...          ...    ...     ...           ...
# 32277     Adm-clerical    Unmarried  White  Female             0
# 32367  Protective-serv      Husband  White    Male          2653
# 32459  Exec-managerial      Husband  White    Male             0
# 32494          Unknown    Unmarried  White    Male             0
# 32525          Unknown    Unmarried  White  Female             0
#
#        capital-loss  hours-per-week native-country salary
# 74                0              20  United-States  <=50K
# 222            2206              40  United-States  <=50K
# 430               0              24  United-States  <=50K
# 918               0              30  United-States  <=50K
# 1040              0              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32277             0              25  United-States  <=50K
# 32367             0              40  United-States  <=50K
# 32459             0               3         Poland  <=50K
# 32494             0               3  United-States  <=50K
# 32525             0               1        Unknown  <=50K
#
# [143 rows x 14 columns]

# %% [markdown]
# hours-per-week

# %%
plt.figure(figsize=(8,6))
plt.subplot(1, 2, 1)
sns.boxplot(data = df['hours-per-week'], whis=4)
plt.subplot(1, 2, 2)
sns.histplot(data = df['hours-per-week'], bins=30)
# Out:
# C:\Users\jawed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jawed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='hours-per-week', ylabel='Count'>

# %%
df[df['hours-per-week'] > 85]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 272     50  Self-emp-not-inc   30653       Masters  Married-civ-spouse
# 935     37           Private  176900       HS-grad  Married-civ-spouse
# 1172    25           Private  404616       Masters  Married-civ-spouse
# 1417    31           Private  179186     Bachelors  Married-civ-spouse
# 1730    24           Private  180060       Masters       Never-married
# ...    ...               ...     ...           ...                 ...
# 31699   43  Self-emp-not-inc  163108  Some-college  Married-civ-spouse
# 31849   21  Self-emp-not-inc  304602     Assoc-voc       Never-married
# 32402   42           Private  288154  Some-college  Married-civ-spouse
# 32469   58      Self-emp-inc  181974     Doctorate       Never-married
# 32531   30           Unknown   33811     Bachelors       Never-married
#
#             occupation relationship                race     sex  capital-gain  \
# 272    Farming-fishing      Husband               White    Male          2407
# 935       Craft-repair      Husband               White    Male             0
# 1172   Farming-fishing    Unmarried               White    Male             0
# 1417             Sales      Husband               Black    Male             0
# 1730   Exec-managerial    Unmarried               White    Male          6849
# ...                ...          ...                 ...     ...           ...
# 31699  Farming-fishing      Husband               White    Male             0
# 31849  Farming-fishing    Unmarried               White    Male             0
# 32402     Craft-repair      Husband               White    Male             0
# 32469   Prof-specialty    Unmarried               White  Female             0
# 32531          Unknown    Unmarried  Asian-Pac-Islander  Female             0
#
#        capital-loss  hours-per-week native-country salary
# 272               0              98  United-States  <=50K
# 935               0              99  United-States   >50K
# 1172              0              99  United-States   >50K
# 1417              0              90  United-States   >50K
# 1730              0              90  United-States  <=50K
# ...             ...             ...            ...    ...
# 31699             0              99  United-States  <=50K
# 31849             0              98  United-States  <=50K
# 32402             0              89  United-States   >50K
# 32469             0              99        Unknown  <=50K
# 32531             0              99  United-States  <=50K
#
# [146 rows x 14 columns]

# %%
df[df['hours-per-week'] > 85][['relationship', 'race']].value_counts()
# Out:
# relationship  race
# Husband       White                 80
# Unmarried     White                 45
# Husband       Black                  6
# Unmarried     Black                  5
# Wife          White                  4
# Husband       Asian-Pac-Islander     3
# Unmarried     Asian-Pac-Islander     2
# Husband       Other                  1
# Name: count, dtype: int64

# %% [markdown]
# ## After looking att the outliers you can drop the rows which actually does not make any sense

# %%
df[(df.age > 80) & (df['hours-per-week'] > 55)]
# Out:
#        age  workclass  fnlwgt    education      marital-status  \
# 5370    90  Local-gov  227796      Masters  Married-civ-spouse
# 7720    84    Private  241065      Masters       Never-married
# 8806    90    Private   87372  Prof-school  Married-civ-spouse
# 12830   81    Private  201398      Masters             Widowed
# 15356   90    Private   90523      HS-grad             Widowed
#
#              occupation relationship   race   sex  capital-gain  capital-loss  \
# 5370    Exec-managerial      Husband  White  Male         20051             0
# 7720     Prof-specialty    Unmarried  White  Male             0             0
# 8806     Prof-specialty      Husband  White  Male         20051             0
# 12830    Prof-specialty    Unmarried  White  Male             0             0
# 15356  Transport-moving    Unmarried  White  Male             0             0
#
#        hours-per-week native-country salary
# 5370               60  United-States   >50K
# 7720               66  United-States  <=50K
# 8806               72  United-States   >50K
# 12830              60        Unknown  <=50K
# 15356              99  United-States  <=50K

# %%
df.shape
# Out:
# (32561, 14)

# %%
drop_index = df[(df.age > 80) & (df['hours-per-week'] > 55)].index
df.drop(index=drop_index, inplace=True)

# %%
df.shape
# Out:
# (32556, 14)

# %% [markdown]
# ## how many of each race are represented in this dataset

# %%
sns.countplot(x = "race", data = df)
# Out:
# C:\Users\jawed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jawed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\jawed\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='race', ylabel='count'>

# %% [markdown]
# ## what is average age of men/women

# %%
df[df.sex == 'Male']['age'].mean()
# Out:
# 39.42263025017213

# %%
df[df.sex == 'Female']['age'].mean()
# Out:
# 36.85823043357163

# %%
df.groupby("sex")['age'].mean()
# Out:
# sex
# Female    36.85823
# Male      39.42263
# Name: age, dtype: float64

# %% [markdown]
# ## what is the percent of people who have a bachelor's degree

# %%
df[df.education == 'Bachelors'].shape[0] / len(df)
# Out:
# 0.164485809067453

# %%
df[df.education == 'Bachelors'].shape[0] / len(df) * 100
# Out:
# 16.4485809067453

# %%
round(df[df.education == 'Bachelors'].shape[0] / len(df) * 100, 2)
# Out:
# 16.45

# %% [markdown]
# ## what percent of people with advanced education(bachelors, masters, or doctorate) make more than 50K?

# %%
adv_edu = df[(df.education == 'Bachelors') | (df.education == 'Masters') | (df.education == 'Doctorate')]
adv_edu
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 0         Adm-clerical    Unmarried               White    Male          2174
# 1      Exec-managerial      Husband               White    Male             0
# 4       Prof-specialty         Wife               Black  Female             0
# 5      Exec-managerial         Wife               White  Female             0
# 8       Prof-specialty    Unmarried               White  Female         14084
# ...                ...          ...                 ...     ...           ...
# 32538   Prof-specialty    Unmarried               Black  Female         15020
# 32539          Unknown      Husband               White    Male             0
# 32544    Other-service    Unmarried               Other  Female             0
# 32553     Tech-support    Unmarried  Asian-Pac-Islander    Male             0
# 32554  Exec-managerial      Husband               White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 0                 0              40  United-States  <=50K
# 1                 0              13  United-States  <=50K
# 4                 0              40           Cuba  <=50K
# 5                 0              40  United-States  <=50K
# 8                 0              50  United-States   >50K
# ...             ...             ...            ...    ...
# 32538             0              45  United-States   >50K
# 32539             0              10  United-States   >50K
# 32544             0              30  United-States  <=50K
# 32553             0              11         Taiwan  <=50K
# 32554             0              40  United-States   >50K
#
# [7488 rows x 14 columns]

# %%
adv_edu[adv_edu.salary == ">50K"]
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 8       31           Private   45781    Masters       Never-married
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# 19      43  Self-emp-not-inc  292175    Masters            Divorced
# 20      40           Private  193524  Doctorate  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 8       Prof-specialty    Unmarried               White  Female         14084
# 9      Exec-managerial      Husband               White    Male          5178
# 11      Prof-specialty      Husband  Asian-Pac-Islander    Male             0
# 19     Exec-managerial    Unmarried               White  Female             0
# 20      Prof-specialty      Husband               White    Male             0
# ...                ...          ...                 ...     ...           ...
# 32533  Exec-managerial      Husband  Asian-Pac-Islander    Male             0
# 32536  Exec-managerial    Unmarried               White  Female             0
# 32538   Prof-specialty    Unmarried               Black  Female         15020
# 32539          Unknown      Husband               White    Male             0
# 32554  Exec-managerial      Husband               White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 8                 0              50  United-States   >50K
# 9                 0              40  United-States   >50K
# 11                0              40          India   >50K
# 19                0              45  United-States   >50K
# 20                0              60  United-States   >50K
# ...             ...             ...            ...    ...
# 32533             0              50          Japan   >50K
# 32536             0              55  United-States   >50K
# 32538             0              45  United-States   >50K
# 32539             0              10  United-States   >50K
# 32554             0              40  United-States   >50K
#
# [3485 rows x 14 columns]

# %%
adv_edu[adv_edu.salary == ">50K"].shape[0]/len(adv_edu)*100
# Out:
# 46.54113247863248

# %%
adv_edu.salary.value_counts(normalize=True)
# Out:
# salary
# <=50K    0.534589
# >50K     0.465411
# Name: proportion, dtype: float64

# %% [markdown]
# ## what percent of people without advanced education(bachelors, masters, or doctorate) make more than 50K?

# %%
not_adv_edu = df[~(df.education == 'Bachelors') | (df.education == 'Masters') | (df.education == 'Doctorate')]
not_adv_edu
# Out:
#        age         workclass  fnlwgt   education         marital-status  \
# 2       38           Private  215646     HS-grad               Divorced
# 3       53           Private  234721        11th     Married-civ-spouse
# 5       37           Private  284582     Masters     Married-civ-spouse
# 6       49           Private  160187         9th  Married-spouse-absent
# 7       52  Self-emp-not-inc  209642     HS-grad     Married-civ-spouse
# ...    ...               ...     ...         ...                    ...
# 32556   27           Private  257302  Assoc-acdm     Married-civ-spouse
# 32557   40           Private  154374     HS-grad     Married-civ-spouse
# 32558   58           Private  151910     HS-grad                Widowed
# 32559   22           Private  201490     HS-grad          Never-married
# 32560   52      Self-emp-inc  287927     HS-grad     Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 2      Handlers-cleaners    Unmarried  White    Male             0
# 3      Handlers-cleaners      Husband  Black    Male             0
# 5        Exec-managerial         Wife  White  Female             0
# 6          Other-service    Unmarried  Black  Female             0
# 7        Exec-managerial      Husband  White    Male             0
# ...                  ...          ...    ...     ...           ...
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Unmarried  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 2                 0              40  United-States  <=50K
# 3                 0              40  United-States  <=50K
# 5                 0              40  United-States  <=50K
# 6                 0              16        Jamaica  <=50K
# 7                 0              45  United-States   >50K
# ...             ...             ...            ...    ...
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K
#
# [27201 rows x 14 columns]

# %%
not_adv_edu.salary.value_counts(normalize=True)
# Out:
# salary
# <=50K    0.793463
# >50K     0.206537
# Name: proportion, dtype: float64
