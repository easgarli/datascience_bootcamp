# %% [markdown]
# <a id="1"></a>
# <span style="display: block; text-align: center; background-color: #40E0D0; font-family: Times New Roman; color: white; padding: 14px; line-height: 1; border-radius: 20px; font-size: 2em;">EXPLORATORY DATA ANALYSIS ROADMAP</span>

# %%
# for analysis
import numpy as np
import pandas as pd
# for visualization
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# plotly for visualization
import plotly
import plotly.express as px
import plotly.graph_objects as go
# for missing values matrix
import missingno as msno
# for showing the graphics
# %matplotlib inline
# to see all the columns
pd.set_option('display.max_columns', None)
# platform to access python version
import platform
# for warnings
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
df = pd.read_csv('co2.csv')

# %%
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# 1              M6         Z                              11.2
# 2             AV7         Z                               6.0
# 3             AS6         Z                              12.7
# 4             AS6         Z                              12.1
# ...           ...       ...                               ...
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                              33                  196
# 1                              29                  221
# 2                              48                  136
# 3                              25                  255
# 4                              27                  244
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [7385 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %%
#select columns of object type from a dataframe
df_object = df.select_dtypes(include='object')
df_object
# Out:
#        Make        Model   Vehicle Class Transmission Fuel Type
# 0     ACURA          ILX         COMPACT          AS5         Z
# 1     ACURA          ILX         COMPACT           M6         Z
# 2     ACURA   ILX HYBRID         COMPACT          AV7         Z
# 3     ACURA      MDX 4WD     SUV - SMALL          AS6         Z
# 4     ACURA      RDX AWD     SUV - SMALL          AS6         Z
# ...     ...          ...             ...          ...       ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL          AS8         Z
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL          AS8         Z
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL          AS8         Z
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD          AS8         Z
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD          AS8         Z
#
# [7385 rows x 5 columns]

# %%
#select columns of numerical type from a dataframe
df_numeric = df.select_dtypes(include='number')
df_numeric
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                              33                  196
# 1                              29                  221
# 2                              48                  136
# 3                              25                  255
# 4                              27                  244
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [7385 rows x 7 columns]

# %%
from summarytools import dfSummary

# %%
dfSummary(df)
# Out:
# <style type="text/css">
# #T_a2ab0 thead>tr>th {
#   text-align: left;
# }
# #T_a2ab0_row0_col0, #T_a2ab0_row1_col0, #T_a2ab0_row2_col0, #T_a2ab0_row3_col0, #T_a2ab0_row4_col0, #T_a2ab0_row5_col0, #T_a2ab0_row6_col0, #T_a2ab0_row7_col0, #T_a2ab0_row8_col0, #T_a2ab0_row9_col0, #T_a2ab0_row10_col0, #T_a2ab0_row11_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_a2ab0_row0_col1, #T_a2ab0_row1_col1, #T_a2ab0_row2_col1, #T_a2ab0_row3_col1, #T_a2ab0_row4_col1, #T_a2ab0_row5_col1, #T_a2ab0_row6_col1, #T_a2ab0_row7_col1, #T_a2ab0_row8_col1, #T_a2ab0_row9_col1, #T_a2ab0_row10_col1, #T_a2ab0_row11_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_a2ab0_row0_col2, #T_a2ab0_row1_col2, #T_a2ab0_row2_col2, #T_a2ab0_row3_col2, #T_a2ab0_row4_col2, #T_a2ab0_row5_col2, #T_a2ab0_row6_col2, #T_a2ab0_row7_col2, #T_a2ab0_row8_col2, #T_a2ab0_row9_col2, #T_a2ab0_row10_col2, #T_a2ab0_row11_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_a2ab0_row0_col3, #T_a2ab0_row1_col3, #T_a2ab0_row2_col3, #T_a2ab0_row3_col3, #T_a2ab0_row4_col3, #T_a2ab0_row5_col3, #T_a2ab0_row6_col3, #T_a2ab0_row7_col3, #T_a2ab0_row8_col3, #T_a2ab0_row9_col3, #T_a2ab0_row10_col3, #T_a2ab0_row11_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_a2ab0_row0_col4, #T_a2ab0_row1_col4, #T_a2ab0_row2_col4, #T_a2ab0_row3_col4, #T_a2ab0_row4_col4, #T_a2ab0_row5_col4, #T_a2ab0_row6_col4, #T_a2ab0_row7_col4, #T_a2ab0_row8_col4, #T_a2ab0_row9_col4, #T_a2ab0_row10_col4, #T_a2ab0_row11_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_a2ab0_row0_col5, #T_a2ab0_row1_col5, #T_a2ab0_row2_col5, #T_a2ab0_row3_col5, #T_a2ab0_row4_col5, #T_a2ab0_row5_col5, #T_a2ab0_row6_col5, #T_a2ab0_row7_col5, #T_a2ab0_row8_col5, #T_a2ab0_row9_col5, #T_a2ab0_row10_col5, #T_a2ab0_row11_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_a2ab0">
#   <caption><strong>Data Frame Summary</strong><br>__<br>Dimensions: 7,385 x 12<br>Duplicates: 1,103</caption>
#   <thead>
#     <tr>
#       <th id="T_a2ab0_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_a2ab0_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_a2ab0_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_a2ab0_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_a2ab0_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_a2ab0_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a2ab0_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a2ab0_row0_col1" class="data row0 col1" ><strong>Make</strong><br>[object]</td>
#       <td id="T_a2ab0_row0_col2" class="data row0 col2" >1. FORD<br>2. CHEVROLET<br>3. BMW<br>4. MERCEDES-BENZ<br>5. PORSCHE<br>6. TOYOTA<br>7. GMC<br>8. AUDI<br>9. NISSAN<br>10. JEEP<br>11. other</td>
#       <td id="T_a2ab0_row0_col3" class="data row0 col3" >628 (8.5%)<br>588 (8.0%)<br>527 (7.1%)<br>419 (5.7%)<br>376 (5.1%)<br>330 (4.5%)<br>328 (4.4%)<br>286 (3.9%)<br>259 (3.5%)<br>251 (3.4%)<br>3,393 (45.9%)</td>
#       <td id="T_a2ab0_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_a2ab0_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a2ab0_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a2ab0_row1_col1" class="data row1 col1" ><strong>Model</strong><br>[object]</td>
#       <td id="T_a2ab0_row1_col2" class="data row1 col2" >1. F-150 FFV 4X4<br>2. F-150 FFV<br>3. MUSTANG<br>4. FOCUS FFV<br>5. SONIC<br>6. SONIC 5<br>7. F-150 4X4<br>8. F-150<br>9. ACCORD<br>10. COMPASS<br>11. other</td>
#       <td id="T_a2ab0_row1_col3" class="data row1 col3" >32 (0.4%)<br>32 (0.4%)<br>27 (0.4%)<br>24 (0.3%)<br>20 (0.3%)<br>20 (0.3%)<br>20 (0.3%)<br>20 (0.3%)<br>19 (0.3%)<br>19 (0.3%)<br>7,152 (96.8%)</td>
#       <td id="T_a2ab0_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_a2ab0_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a2ab0_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a2ab0_row2_col1" class="data row2 col1" ><strong>Vehicle Class</strong><br>[object]</td>
#       <td id="T_a2ab0_row2_col2" class="data row2 col2" >1. SUV - SMALL<br>2. MID-SIZE<br>3. COMPACT<br>4. SUV - STANDARD<br>5. FULL-SIZE<br>6. SUBCOMPACT<br>7. PICKUP TRUCK - STANDARD<br>8. TWO-SEATER<br>9. MINICOMPACT<br>10. STATION WAGON - SMALL<br>11. other</td>
#       <td id="T_a2ab0_row2_col3" class="data row2 col3" >1,217 (16.5%)<br>1,133 (15.3%)<br>1,022 (13.8%)<br>735 (10.0%)<br>639 (8.7%)<br>606 (8.2%)<br>538 (7.3%)<br>460 (6.2%)<br>326 (4.4%)<br>252 (3.4%)<br>457 (6.2%)</td>
#       <td id="T_a2ab0_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_a2ab0_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a2ab0_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a2ab0_row3_col1" class="data row3 col1" ><strong>Engine Size(L)</strong><br>[float64]</td>
#       <td id="T_a2ab0_row3_col2" class="data row3 col2" >Mean (sd) : 3.2 (1.4)<br>min < med < max:<br>0.9 < 3.0 < 8.4<br>IQR (CV) : 1.7 (2.3)</td>
#       <td id="T_a2ab0_row3_col3" class="data row3 col3" >51 distinct values</td>
#       <td id="T_a2ab0_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_a2ab0_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a2ab0_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a2ab0_row4_col1" class="data row4 col1" ><strong>Cylinders</strong><br>[int64]</td>
#       <td id="T_a2ab0_row4_col2" class="data row4 col2" >1. 4<br>2. 6<br>3. 8<br>4. 12<br>5. 3<br>6. 10<br>7. 5<br>8. 16</td>
#       <td id="T_a2ab0_row4_col3" class="data row4 col3" >3,220 (43.6%)<br>2,446 (33.1%)<br>1,402 (19.0%)<br>151 (2.0%)<br>95 (1.3%)<br>42 (0.6%)<br>26 (0.4%)<br>3 (0.0%)</td>
#       <td id="T_a2ab0_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_a2ab0_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a2ab0_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a2ab0_row5_col1" class="data row5 col1" ><strong>Transmission</strong><br>[object]</td>
#       <td id="T_a2ab0_row5_col2" class="data row5 col2" >1. AS6<br>2. AS8<br>3. M6<br>4. A6<br>5. A8<br>6. AM7<br>7. A9<br>8. AS7<br>9. AV<br>10. M5<br>11. other</td>
#       <td id="T_a2ab0_row5_col3" class="data row5 col3" >1,324 (17.9%)<br>1,211 (16.4%)<br>901 (12.2%)<br>789 (10.7%)<br>490 (6.6%)<br>445 (6.0%)<br>339 (4.6%)<br>319 (4.3%)<br>295 (4.0%)<br>193 (2.6%)<br>1,079 (14.6%)</td>
#       <td id="T_a2ab0_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_a2ab0_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a2ab0_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_a2ab0_row6_col1" class="data row6 col1" ><strong>Fuel Type</strong><br>[object]</td>
#       <td id="T_a2ab0_row6_col2" class="data row6 col2" >1. X<br>2. Z<br>3. E<br>4. D<br>5. N</td>
#       <td id="T_a2ab0_row6_col3" class="data row6 col3" >3,637 (49.2%)<br>3,202 (43.4%)<br>370 (5.0%)<br>175 (2.4%)<br>1 (0.0%)</td>
#       <td id="T_a2ab0_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_a2ab0_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_a2ab0_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_a2ab0_row7_col1" class="data row7 col1" ><strong>Fuel Consumption City (L/100 km)</strong><br>[float64]</td>
#       <td id="T_a2

# %%
def SuperInfo(df, dropna=False):
    """
    Returns a dataframe consisting of datatypes, nuniques, #s of nulls head(1), most frequent item and its frequncy,
    where the column names are indices.
    """
    dt=pd.DataFrame(df.dtypes, columns=["Type"])
    dn=pd.DataFrame(df.nunique(), columns=["Nunique"])
    nonnull=pd.DataFrame(df.isnull().sum(), columns=["#of Missing"])
    firstT=df.head(1).T.rename(columns={0:"First"})
    MostFreqI=pd.DataFrame([df[x].value_counts().head(1).index[0] for x in df.columns], columns=["MostFreqItem"],index=df.columns)
    MostFreqC=pd.DataFrame([df[x].value_counts().head(1).values[0] for x in df.columns], columns=["MostFreqCount"],index=df.columns)
    return pd.concat([dt,dn,nonnull,MostFreqI,MostFreqC,firstT],axis=1)

# %%
SuperInfo(df)
# Out:
#                                      Type  Nunique  #of Missing  \
# Make                               object       42            0
# Model                              object     2053            0
# Vehicle Class                      object       16            0
# Engine Size(L)                    float64       51            0
# Cylinders                           int64        8            0
# Transmission                       object       27            0
# Fuel Type                          object        5            0
# Fuel Consumption City (L/100 km)  float64      211            0
# Fuel Consumption Hwy (L/100 km)   float64      143            0
# Fuel Consumption Comb (L/100 km)  float64      181            0
# Fuel Consumption Comb (mpg)         int64       54            0
# CO2 Emissions(g/km)                 int64      331            0
#
#                                    MostFreqItem  MostFreqCount    First
# Make                                       FORD            628    ACURA
# Model                             F-150 FFV 4X4             32      ILX
# Vehicle Class                       SUV - SMALL           1217  COMPACT
# Engine Size(L)                              2.0           1460      2.0
# Cylinders                                     4           3220        4
# Transmission                                AS6           1324      AS5
# Fuel Type                                     X           3637        Z
# Fuel Consumption City (L/100 km)           10.8            125      9.9
# Fuel Consumption Hwy (L/100 km)             7.8            209      6.7
# Fuel Consumption Comb (L/100 km)            9.4            145      8.5
# Fuel Consumption Comb (mpg)                  25            482       33
# CO2 Emissions(g/km)                         242             85      196

# %%
def value_counts(df):
    for i in df.columns:
        if len(df[i].unique()) < 10:
            print(i)
            print("*****values counts*****")
            print(df[i].value_counts())
            print("")

# %%
value_counts(df)
# Out:
# Cylinders
# *****values counts*****
# Cylinders
# 4     3220
# 6     2446
# 8     1402
# 12     151
# 3       95
# 10      42
# 5       26
# 16       3
# Name: count, dtype: int64
#
# Fuel Type
# *****values counts*****
# Fuel Type
# X    3637
# Z    3202
# E     370
# D     175
# N       1
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1103
