# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("DataAnalyst.csv").copy()

# %%
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4     ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                                    Company Name        Location  \
# 0              Vera Institute of Justice\r\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\r\n3.8    New York, NY
# 2                            Squarespace\r\n3.4    New York, NY
# 3                               Celerity\r\n4.1    New York, NY
# 4                                FanDuel\r\n3.9    New York, NY
# ...                                         ...             ...
# 2248                       Avacend, Inc.\r\n2.5      Denver, CO
# 2249                   Arrow Electronics\r\n2.9  Centennial, CO
# 2250                                   Spiceorb      Denver, CO
# 2251         Contingent Network Services\r\n3.1  Centennial, CO
# 2252                          SCL Health\r\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.8+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
df = df.replace("-1", np.nan).replace(-1,np.nan).replace(-1.0,np.nan)
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4     ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                                    Company Name        Location  \
# 0              Vera Institute of Justice\r\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\r\n3.8    New York, NY
# 2                            Squarespace\r\n3.4    New York, NY
# 3                               Celerity\r\n4.1    New York, NY
# 4                                FanDuel\r\n3.9    New York, NY
# ...                                         ...             ...
# 2248                       Avacend, Inc.\r\n2.5      Denver, CO
# 2249                   Arrow Electronics\r\n2.9  Centennial, CO
# 2250                                   Spiceorb      Denver, CO
# 2251         Contingent Network Services\r\n3.1  Centennial, CO
# 2252                          SCL Health\r\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees   1961.0
# 1         New York, NY        10000+ employees   1893.0
# 2         New York, NY  1001 to 5000 employees   2003.0
# 3           McLean, VA    201 to 500 employees   2002.0
# 4         New York, NY   501 to 1000 employees   2009.0
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees      NaN
# 2249    Centennial, CO        10000+ employees   1935.0
# 2250               NaN                     NaN      NaN
# 2251  West Chester, OH    201 to 500 employees   1984.0
# 2252    Broomfield, CO        10000+ employees   1864.0
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                             NaN                                      NaN
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                               NaN                         NaN
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                   NaN       True
# 1                                                   NaN        NaN
# 2                                               GoDaddy        NaN
# 3                                                   NaN        NaN
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                NaN        NaN
# 2249                     Avnet, Ingram Micro, Tech Data        NaN
# 2250                                                NaN        NaN
# 2251                                                NaN        NaN
# 2252  Centura Health, HealthONE, Denver Health and H...        NaN
#
# [2253 rows x 16 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1)
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\r\n\r\nProvides analytical and techni...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\r\nRemote:Yes\r\n...     4.1
# 4     ABOUT FANDUEL GROUP\r\n\r\nFanDuel Group is a ...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\r\nSenior Data Analyst (Corporate Au...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...     NaN
# 2251  Summary\r\n\r\nResponsible for working cross-f...     3.1
# 2252  You.\r\n\r\nYou bring your body, mind, heart a...     3.4
#
#                                    Company Name        Location  \
# 0              Vera Institute of Justice\r\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\r\n3.8    New York, NY
# 2                            Squarespace\r\n3.4    New York, NY
# 3                               Celerity\r\n4.1    New York, NY
# 4                                FanDuel\r\n3.9    New York, NY
# ...                                         ...             ...
# 2248                       Avacend, Inc.\r\n2.5      Denver, CO
# 2249                   Arrow Electronics\r\n2.9  Centennial, CO
# 2250                                   Spiceorb      Denver, CO
# 2251         Contingent Network Services\r\n3.1  Centennial, CO
# 2252                          SCL Health\r\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees   1961.0
# 1         New York, NY        10000+ employees   1893.0
# 2         New York, NY  1001 to 5000 employees   2003.0
# 3           McLean, VA    201 to 500 employees   2002.0
# 4         New York, NY   501 to 1000 employees   2009.0
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees      NaN
# 2249    Centennial, CO        10000+ employees   1935.0
# 2250               NaN                     NaN      NaN
# 2251  West Chester, OH    201 to 500 employees   1984.0
# 2252    Broomfield, CO        10000+ employees   1864.0
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                             NaN                                      NaN
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                               NaN                         NaN
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                   NaN       True
# 1                                                   NaN        NaN
# 2                                               GoDaddy        NaN
# 3                                                   NaN        NaN
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                NaN        NaN
# 2249                     Avnet, Ingram Micro, Tech Data        NaN
# 2250                                                NaN        NaN
# 2251                                                NaN        NaN
# 2252  Centura Health, HealthONE, Denver Health and H...        NaN
#
# [2253 rows x 15 columns]

# %%
df["Job Title"].value_counts()
# Out:
# Job Title
# Data Analyst                        405
# Senior Data Analyst                  90
# Junior Data Analyst                  30
# Business Data Analyst                28
# Sr. Data Analyst                     21
#                                    ...
# Data Analyst – Level II               1
# Data Analyst/Programmer               1
# Data Services Business Analyst 2      1
# Call Center Data Analyst              1
# Senior Quality Data Analyst           1
# Name: count, Length: 1272, dtype: int64

# %%
df["Job Title"]=df["Job Title"].replace("Sr. Data Analyst","Senior Data Analyst")

df["Job Title"]=df["Job Title"].replace("Sr Data Analyst","Senior Data Analyst")

df["Job Title"]=df["Job Title"].replace("Jr. Data Analyst","Junior Data Analyst")

df["Job Title"]=df["Job Title"].replace("Jr Data Analyst","Junior Data Analyst")

# %%
df["Job Title"].value_counts()
# Out:
# Job Title
# Data Analyst                                                 405
# Senior Data Analyst                                          120
# Junior Data Analyst                                           33
# Business Data Analyst                                         28
# Data Analyst Junior                                           17
#                                                             ...
# Data Analyst/Programmer                                        1
# Data Services Business Analyst 2                               1
# Call Center Data Analyst                                       1
# Senior Global Data Analyst / Power BI Dashboard Developer      1
# Senior Quality Data Analyst                                    1
# Name: count, Length: 1268, dtype: int64

# %%
df["Job Title"].nunique()
# Out:
# 1268

# %%
df["Job Title"].value_counts()[:20]
# Out:
# Job Title
# Data Analyst               405
# Senior Data Analyst        120
# Junior Data Analyst         33
# Business Data Analyst       28
# Data Analyst Junior         17
# Data Analyst II             17
# Data Quality Analyst        17
# Data Governance Analyst     16
# Lead Data Analyst           15
# Data Reporting Analyst      13
# Financial Data Analyst      12
# Data Analyst III            11
# Data Analyst I              11
# Marketing Data Analyst       9
# Data Management Analyst      8
# Data Warehouse Analyst       8
# SQL Data Analyst             7
# Data Science Analyst         7
# Technical Data Analyst       7
# Healthcare Data Analyst      6
# Name: count, dtype: int64

# %%
df['Salary Estimate']=df['Salary Estimate'].str.split().str[0]
df['Salary Estimate']
# Out:
# 0        $37K-$66K
# 1        $37K-$66K
# 2        $37K-$66K
# 3        $37K-$66K
# 4        $37K-$66K
#            ...
# 2248    $78K-$104K
# 2249    $78K-$104K
# 2250    $78K-$104K
# 2251    $78K-$104K
# 2252    $78K-$104K
# Name: Salary Estimate, Length: 2253, dtype: object

# %%
df["Salary Min"] = df["Salary Estimate"].str.split("-").str[0].str.strip("$").str.replace("K","000").astype("float")
df["Salary Max"] = df["Salary Estimate"].str.split("-").str[1].str.strip("$").str.replace("K","000").astype("float")

# %%
df["Salary Average"] = (df["Salary Min"] + df["Salary Max"]) / 2

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df[df["Salary Estimate"].isnull()]
# Out:
#                                       Job Title Salary Estimate  \
# 2149  Configuration/Data Management Analyst III             NaN
#
#                                         Job Description  Rating  \
# 2149  Job Description\r\nPosition Title: Configurati...     4.4
#
#            Company Name  Location  Headquarters                 Size  Founded  \
# 2149  Protingent\r\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees   2001.0
#
#       Type of ownership                Industry             Sector  \
# 2149  Company - Private  Staffing & Outsourcing  Business Services
#
#                        Revenue Competitors Easy Apply  Salary Min  Salary Max  \
# 2149  $25 to $50 million (USD)         NaN        NaN         NaN         NaN
#
#       Salary Average
# 2149             NaN

# %%
df[df["Company Name"]== "Protingent\r\n4.4"]
# Out:
#                                               Job Title Salary Estimate  \
# 2123  Engines Configuration and Data Management Analyst      $55K-$101K
# 2149          Configuration/Data Management Analyst III             NaN
#
#                                         Job Description  Rating  \
# 2123  Job Description\r\nPosition Title: Engines Con...     4.4
# 2149  Job Description\r\nPosition Title: Configurati...     4.4
#
#            Company Name  Location  Headquarters                 Size  Founded  \
# 2123  Protingent\r\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees   2001.0
# 2149  Protingent\r\n4.4  Kent, WA  Bellevue, WA  51 to 200 employees   2001.0
#
#       Type of ownership                Industry             Sector  \
# 2123  Company - Private  Staffing & Outsourcing  Business Services
# 2149  Company - Private  Staffing & Outsourcing  Business Services
#
#                        Revenue Competitors Easy Apply  Salary Min  Salary Max  \
# 2123  $25 to $50 million (USD)         NaN        NaN     55000.0    101000.0
# 2149  $25 to $50 million (USD)         NaN        NaN         NaN         NaN
#
#       Salary Average
# 2123         78000.0
# 2149             NaN

# %%
df.drop([2149], inplace=True)

# %%
df["Salary Estimate"].isnull().sum()
# Out:
# 0

# %%
df["python"] = df["Job Description"].str.lower().str.contains("python") 
df["tableau"] = df["Job Description"].str.lower().str.contains("tableau") 
df["excel"] = df["Job Description"].str.lower().str.contains("excel") 
df["sql"] = df["Job Description"].str.lower().str.contains("sql")

# %%
df.sample(5)
# Out:
#                                     Job Title Salary Estimate  \
# 247            Reporting Analyst Data Analyst       $45K-$88K
# 370    Data Analyst with Data Lineage/Rochade      $98K-$114K
# 1520                      Data Analyst Intern      $89K-$151K
# 13                        Senior Data Analyst       $37K-$66K
# 185   Junior Data Analytics Solutions Analyst      $60K-$110K
#
#                                         Job Description  Rating  \
# 247   Job Description\r\nTitle: Reporting Analyst / ...     NaN
# 370   The Senior Business Consultant will be involve...     4.0
# 1520  Requisition ID: 258554\r\nWork Area: Software-...     4.6
# 13    About Known\r\n\r\nKnown is a modern marketing...     3.0
# 185   Praescient Analytics, LLC (Praescient) is a Ve...     3.1
#
#                             Company Name          Location       Headquarters  \
# 247                         APR Staffing  Lake Success, NY                NaN
# 370   Reliable Software Resources\r\n4.0  Florham Park, NJ     Northville, MI
# 1520                          SAP\r\n4.6     Palo Alto, CA  Walldorf, Germany
# 13                          Known\r\n3.0      New York, NY       New York, NY
# 185          Praescient Analytics\r\n3.1      New York, NY     Alexandria, VA
#
#                        Size  Founded  Type of ownership  ...  \
# 247                     NaN      NaN                NaN  ...
# 370   501 to 1000 employees   2004.0  Company - Private  ...
# 1520       10000+ employees   1972.0   Company - Public  ...
# 13     201 to 500 employees   2004.0  Company - Private  ...
# 185     51 to 200 employees   2011.0  Company - Private  ...
#
#                          Revenue                    Competitors Easy Apply  \
# 247                          NaN                            NaN        NaN
# 370    $50 to $100 million (USD)                            NaN        NaN
# 1520          $10+ billion (USD)  Salesforce, Oracle, Microsoft        NaN
# 13    $100 to $500 million (USD)                            NaN       True
# 185     $10 to $25 million (USD)                            NaN        NaN
#
#      Salary Min Salary Max  Salary Average  python  tableau  excel    sql
# 247     45000.0    88000.0         66500.0   False    False   True   True
# 370     98000.0   114000.0        106000.0   False    False  False  False
# 1520    89000.0   151000.0        120000.0   False    False  False  False
# 13      37000.0    66000.0         51500.0    True    False   True   True
# 185     60000.0   110000.0         85000.0    True     True   True   True
#
# [5 rows x 22 columns]

# %%
df["python"].value_counts(normalize=True)
# Out:
# python
# False    0.71714
# True     0.28286
# Name: proportion, dtype: float64

# %%
df["sql"].value_counts(normalize=True)
# Out:
# sql
# True     0.616341
# False    0.383659
# Name: proportion, dtype: float64

# %%
df["tableau"].value_counts(normalize=True)
# Out:
# tableau
# False    0.724689
# True     0.275311
# Name: proportion, dtype: float64

# %%
df["Rating"]
# Out:
# 0       3.2
# 1       3.8
# 2       3.4
# 3       4.1
# 4       3.9
#        ...
# 2248    2.5
# 2249    2.9
# 2250    NaN
# 2251    3.1
# 2252    3.4
# Name: Rating, Length: 2252, dtype: float64

# %%
df[["Company Name", "Rating", "Salary Estimate"]]
# Out:
#                                    Company Name  Rating Salary Estimate
# 0              Vera Institute of Justice\r\n3.2     3.2       $37K-$66K
# 1     Visiting Nurse Service of New York\r\n3.8     3.8       $37K-$66K
# 2                            Squarespace\r\n3.4     3.4       $37K-$66K
# 3                               Celerity\r\n4.1     4.1       $37K-$66K
# 4                                FanDuel\r\n3.9     3.9       $37K-$66K
# ...                                         ...     ...             ...
# 2248                       Avacend, Inc.\r\n2.5     2.5      $78K-$104K
# 2249                   Arrow Electronics\r\n2.9     2.9      $78K-$104K
# 2250                                   Spiceorb     NaN      $78K-$104K
# 2251         Contingent Network Services\r\n3.1     3.1      $78K-$104K
# 2252                          SCL Health\r\n3.4     3.4      $78K-$104K
#
# [2252 rows x 3 columns]

# %%
df["Company Name"].isnull().sum()
# Out:
# 1

# %%
df[df["Company Name"].isnull()]
# Out:
#          Job Title Salary Estimate  \
# 1860  Data Analyst       $53K-$99K
#
#                                         Job Description  Rating Company Name  \
# 1860  Kindred at Home, part of the Kindred at Home f...     NaN          NaN
#
#              Location Headquarters Size  Founded Type of ownership  ...  \
# 1860  Mooresville, NC          NaN  NaN      NaN               NaN  ...
#
#      Revenue Competitors Easy Apply Salary Min Salary Max  Salary Average  \
# 1860     NaN         NaN        NaN    53000.0    99000.0         76000.0
#
#       python  tableau  excel   sql
# 1860   False    False   True  True
#
# [1 rows x 22 columns]

# %%
df.drop([1860],inplace=True)

# %%
df["Company Name"] = df["Company Name"].str.split("\r").str[0]
df["Company Name"]
# Out:
# 0                Vera Institute of Justice
# 1       Visiting Nurse Service of New York
# 2                              Squarespace
# 3                                 Celerity
# 4                                  FanDuel
#                        ...
# 2248                         Avacend, Inc.
# 2249                     Arrow Electronics
# 2250                              Spiceorb
# 2251           Contingent Network Services
# 2252                            SCL Health
# Name: Company Name, Length: 2251, dtype: object

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply', 'Salary Min', 'Salary Max', 'Salary Average', 'python',
#        'tableau', 'excel', 'sql'],
#       dtype='object')

# %%
df["Industry"].value_counts()
# Out:
# Industry
# IT Services                            325
# Staffing & Outsourcing                 322
# Health Care Services & Hospitals       151
# Computer Hardware & Software           111
# Consulting                             111
#                                       ...
# Truck Rental & Leasing                   1
# News Outlet                              1
# Catering & Food Service Contractors      1
# Chemical Manufacturing                   1
# Hotels, Motels, & Resorts                1
# Name: count, Length: 88, dtype: int64

# %%
df["Industry"].isnull().sum()
# Out:
# 352

# %%
df["Sector"].value_counts()
# Out:
# Sector
# Information Technology                570
# Business Services                     523
# Finance                               169
# Health Care                           151
# Education                              52
# Insurance                              51
# Accounting & Legal                     43
# Media                                  42
# Manufacturing                          40
# Retail                                 38
# Government                             36
# Biotech & Pharmaceuticals              33
# Non-Profit                             26
# Aerospace & Defense                    22
# Transportation & Logistics             20
# Construction, Repair & Maintenance     16
# Consumer Services                      14
# Oil, Gas, Energy & Utilities           13
# Real Estate                            12
# Telecommunications                     11
# Restaurants, Bars & Food Services       8
# Arts, Entertainment & Recreation        7
# Mining & Metals                         1
# Travel & Tourism                        1
# Name: count, dtype: int64

# %%
df["Sector"].isnull().sum()
# Out:
# 352

# %%
def check_isnull(df):
    for col in df.columns:
        if df[col].isnull().sum() > 0:
            print(col, df[col].isnull().sum())
check_isnull(df)
# Out:
# Rating 271
# Headquarters 171
# Size 162
# Founded 659
# Type of ownership 162
# Industry 352
# Sector 352
# Revenue 162
# Competitors 1730
# Easy Apply 2171

# %%
def missing_values(df):
    missing_number = df.isnull().sum().sort_values(ascending=False)
    missing_percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_values = pd.concat([missing_number, missing_percent], axis=1, keys=['Missing_Number', 'Missing_Percent'])
    return missing_values[missing_values['Missing_Number']>0]

# %%
missing_values(df)
# Out:
#                    Missing_Number  Missing_Percent
# Easy Apply                   2171         0.964460
# Competitors                  1730         0.768547
# Founded                       659         0.292759
# Sector                        352         0.156375
# Industry                      352         0.156375
# Rating                        271         0.120391
# Headquarters                  171         0.075966
# Size                          162         0.071968
# Type of ownership             162         0.071968
# Revenue                       162         0.071968

# %%
def first_look(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()/df.shape[0]*100, 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print("Value counts   : \n", df[col].value_counts(dropna = False))

# %%
first_look("Sector")
# Out:
# column name    :  Sector
# --------------------------------
# per_of_nulls   :  % 15.64
# num_of_nulls   :  352
# num_of_uniques :  24
# Value counts   :
#  Sector
# Information Technology                570
# Business Services                     523
# NaN                                   352
# Finance                               169
# Health Care                           151
# Education                              52
# Insurance                              51
# Accounting & Legal                     43
# Media                                  42
# Manufacturing                          40
# Retail                                 38
# Government                             36
# Biotech & Pharmaceuticals              33
# Non-Profit                             26
# Aerospace & Defense                    22
# Transportation & Logistics             20
# Construction, Repair & Maintenance     16
# Consumer Services                      14
# Oil, Gas, Energy & Utilities           13
# Real Estate                            12
# Telecommunications                     11
# Restaurants, Bars & Food Services       8
# Arts, Entertainment & Recreation        7
# Mining & Metals                         1
# Travel & Tourism                        1
# Name: count, dtype: int64

# %%
df_analyst=df[["Job Title","Company Name","Rating","Industry","Sector","Salary Min", "Salary Max","Salary Average", "python", "tableau", "excel", "sql"]].copy()
df_analyst
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                             Company Name  Rating  \
# 0              Vera Institute of Justice     3.2
# 1     Visiting Nurse Service of New York     3.8
# 2                            Squarespace     3.4
# 3                               Celerity     4.1
# 4                                FanDuel     3.9
# ...                                  ...     ...
# 2248                       Avacend, Inc.     2.5
# 2249                   Arrow Electronics     2.9
# 2250                            Spiceorb     NaN
# 2251         Contingent Network Services     3.1
# 2252                          SCL Health     3.4
#
#                                      Industry  \
# 0                           Social Assistance
# 1            Health Care Services & Hospitals
# 2                                    Internet
# 3                                 IT Services
# 4                         Sports & Recreation
# ...                                       ...
# 2248                   Staffing & Outsourcing
# 2249                                Wholesale
# 2250                                      NaN
# 2251  Enterprise Software & Network Solutions
# 2252         Health Care Services & Hospitals
#
#                                 Sector  Salary Min  Salary Max  \
# 0                           Non-Profit     37000.0     66000.0
# 1                          Health Care     37000.0     66000.0
# 2               Information Technology     37000.0     66000.0
# 3               Information Technology     37000.0     66000.0
# 4     Arts, Entertainment & Recreation     37000.0     66000.0
# ...                                ...         ...         ...
# 2248                 Business Services     78000.0    104000.0
# 2249                 Business Services     78000.0    104000.0
# 2250                               NaN     78000.0    104000.0
# 2251            Information Technology     78000.0    104000.0
# 2252                       Health Care     78000.0    104000.0
#
#       Salary Average  python  tableau  excel    sql
# 0            51500.0    True    False  False   True
# 1            51500.0   False    False   True   True
# 2            51500.0    True     True   True   True
# 3            51500.0   False     True  False   True
# 4            51500.0    True    False   True   True
# ...              ...     ...      ...    ...    ...
# 2248         91000.0   False    False  False  False
# 2249         91000.0   False     True  False   True
# 2250         91000.0   False    False   True   True
# 2251         91000.0    True    False  False   True
# 2252         91000.0   False     True   True  False
#
# [2251 rows x 12 columns]

# %%
missing_values(df_analyst)
# Out:
#           Missing_Number  Missing_Percent
# Industry             352         0.156375
# Sector               352         0.156375
# Rating               271         0.120391

# %%
xx=df_analyst["Job Title"].value_counts()[:20]
xx
# Out:
# Job Title
# Data Analyst               404
# Senior Data Analyst        120
# Junior Data Analyst         33
# Business Data Analyst       28
# Data Quality Analyst        17
# Data Analyst Junior         17
# Data Analyst II             17
# Data Governance Analyst     16
# Lead Data Analyst           15
# Data Reporting Analyst      13
# Financial Data Analyst      12
# Data Analyst III            11
# Data Analyst I              11
# Marketing Data Analyst       9
# Data Warehouse Analyst       8
# Data Management Analyst      8
# Data Science Analyst         7
# SQL Data Analyst             7
# Technical Data Analyst       7
# Research Data Analyst        6
# Name: count, dtype: int64
